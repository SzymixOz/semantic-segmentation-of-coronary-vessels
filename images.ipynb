# %%
import utils 
import pandas as pd 
import numpy as np
from IPython.display import clear_output

# %%
data = pd.read_csv('data.csv')

# %%
# images, segmentations = utils.get_data(data, voting=True, images_path='./students_images')

# %%
# for i, (image, seg) in enumerate(zip(images, segmentations)):
#     utils.get_mask(image, seg, name = f'image_{i}', binary=True)
#     clear_output(wait=True)
#     break

# %%
images2, segmentations2 = utils.get_data(data, voting=False, images_path='./students_images')

# %%
for i, (image, seg) in enumerate(zip(images2, segmentations2)):
    utils.get_mask(image, seg, name = f'image_{i}', binary=False)
    # clear_output(wait=True)
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
